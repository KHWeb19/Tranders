# %%
from kafka import KafkaProducer
from json import dumps
import time

# %%
from kafka import KafkaConsumer
from json import loads

# topic, broker list
consumer = KafkaConsumer(
    'test2',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='my-group',
     value_deserializer=lambda x: loads(x.decode('utf-8')),
     consumer_timeout_ms=1000
)

# consumer list를 가져온다
print('[begin] get consumer list')
for message in consumer:
    print(message.value)
print('[end] get consumer list')
# Out:
# [begin] get consumer list
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 17>()
#      15 # consumer list를 가져온다
#      16 print('[begin] get consumer list')
# ---> 17 for message in consumer:
#      18     print(message.value)
#      19 print('[end] get consumer list')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/consumer/group.py:675, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     665 def _poll_once(self, timeout_ms, max_records, update_offsets=True):
#     666     """Do one round of polling. In addition to checking for new data, this does
#     667     any needed heart-beating, auto-commits, and offset updates.
#     668
#    (...)
#     673         dict: Map of topic to list of records (may be empty).
#     674     """
# --> 675     self._coordinator.poll()
#     677     # Fetch positions if we have partitions we're subscribed to that we
#     678     # don't know the offset for
#     679     if not self._subscription.has_all_fetch_positions():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/coordinator/consumer.py:289, in ConsumerCoordinator.poll(self)
#     286             metadata_update = self._client.cluster.request_update()
#     287             self._client.poll(future=metadata_update)
# --> 289         self.ensure_active_group()
#     291     self.poll_heartbeat()
#     293 self._maybe_auto_commit_offsets_async()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/coordinator/base.py:407, in BaseCoordinator.ensure_active_group(self)
#     404 else:
#     405     future = self.join_future
# --> 407 self._client.poll(future=future)
#     409 if future.succeeded():
#     410     self._on_join_complete(self._generation.generation_id,
#     411                            self._generation.member_id,
#     412                            self._generation.protocol,
#     413                            future.value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/opt/anaconda3/lib/python3.9/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
