# %%
# pip install kafka-python

# %%
from kafka import KafkaProducer
from json import dumps


producer = KafkaProducer(acks=0, compression_type='gzip', bootstrap_servers=['127.0.0.1:9092'],
                         value_serializer=lambda x: dumps(x).encode('utf-8'))

# data = {'message' :'result'}
# producer.send('test3', value=data)
# producer.flush()
# print("전송")

# %%
from flask import Flask, url_for, request, jsonify
from flask_cors import CORS, cross_origin
from kafka import KafkaConsumer
from json import loads
import json



def get_kafka_data():
    consumer = KafkaConsumer(
    'test3',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id=None,
     value_deserializer=lambda x: loads(x.decode('utf-8')),
     consumer_timeout_ms=1000
)
    
    result_list = []
    for message in consumer:
        data_dict = {}
        data_dict['content'] = message.value
        result_list.append(data_dict)
    return result_list

app = Flask(__name__)
CORS(app, resources={r'/*': {'origins': '*'}})

@app.route('/kafka-data',methods=['GET'])
@cross_origin()
def new_data():
    data_list = get_kafka_data()
    return jsonify(data_list)

if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Jun/2022 17:30:33] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:31:21] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:38:08] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:38:38] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:38:43] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:40:28] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:40:29] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:40:50] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:41:11] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:41:24] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:42:32] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:43:23] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:43:50] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:43:56] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:45:13] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:45:20] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:54:19] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:56:13] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 17:56:39] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:05:25] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:05:35] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:06:22] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jun/2022 18:06:27] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:06:28] "GET /images/icons/gear.png HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jun/2022 18:06:59] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:07:01] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:07:14] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:07:31] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:08:21] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:08:29] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:10:33] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:11:27] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:12:05] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:13:36] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:14:11] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:16:08] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:16:25] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:16:34] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:16:40] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:41:57] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:48:59] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:49:30] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:49:43] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:50:09] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:50:26] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:51:14] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:52:07] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:55:38] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:55:54] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:56:03] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:56:25] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:57:24] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:57:26] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:58:23] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 18:58:40] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:00:03] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:04:51] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:05:09] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:05:13] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:06:31] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:06:47] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:06:51] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:05] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:10] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:13] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:15] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:24] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:26] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:07:29] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:37:13] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 19:37:15] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 21:00:15] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 21:00:17] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 21:00:18] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 21:00:20] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:05:04] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:05:47] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:06:09] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:08:19] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:09:09] "GET /kafka-data HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2022 23:13:24] "GET /kafka-data HTTP/1.1" 200 -
